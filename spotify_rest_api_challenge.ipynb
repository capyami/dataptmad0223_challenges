# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = '' # CLIENT ID
client_secret = ''# CLIENT SECRET
auth_url =  'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQDR0s7qVyEAa3f2M2wAXITJG73Tc2rz_puCbRgvjoVBrTxMig17AqiPOhdy2rxvfmg6T5lNNJLI_4wwDPUw-4tjMFfM9AX5Bvt6Qyvv77emuahHke-U',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
'''

'''
# Out:
# '\n\n'

# %%
# Here you can complete your endpoint URI
artist_id = '6FBDaR13swtiWwGhX1WQsP/' #artist_id
method_01 = 'related-artists' # method_01
method_02 = 'top-tracks'   # method_2
country = '?country=ES'
full_endpoint = base_url + resource + artist_id + method_01
full_endpoint1 = base_url + resource + artist_id
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/6FBDaR13swtiWwGhX1WQsP/related-artists'

# %%
# Start building your playlist!!!
lst_spo = requests.get(full_endpoint, headers = header_info)
lst_spo
# Out:
# <Response [200]>

# %%
artists_related = lst_spo.json()

# %%
artists_related.keys()
# Out:
# dict_keys(['artists'])

# %%
artists_related['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xklw3WodFZiNNmQt3DIgp'},
#   'followers': {'href': None, 'total': 655886},
#   'genres': ['pop punk', 'socal pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/7xklw3WodFZiNNmQt3DIgp',
#   'id': '7xklw3WodFZiNNmQt3DIgp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9bf03fdd68eecd329f9fde6e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749bf03fdd68eecd329f9fde6e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789bf03fdd68eecd329f9fde6e',
#     'width': 160}],
#   'name': 'Angels & Airwaves',
#   'popularity': 59,
#   'type': 'artist',
#   'uri': 'spotify:artist:7xklw3WodFZiNNmQt3DIgp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gkRNHOOt7QfhhXf0rEnmj'},
#   'followers': {'href': None, 'total': 406254},
#   'genres': ['pop punk', 'punk', 'skate punk'],
#   'href': 'https://api.spotify.com/v1/artists/7gkRNHOOt7QfhhXf0rEnmj',
#   'id': '7gkRNHOOt7QfhhXf0rEnmj',
#   'images': [{'height': 714,
#     'url': 'https://i.scdn.co/image/2ffba921f9db6d1bf44ae63b8a956e3a11fea234',
#     'width': 900},
#    {'height': 508,
#     'url': 'https://i.scdn.co/image/40baeadac6642e10437833f0ba1006eda0d22786',
#     'width': 640},
#    {'height': 159,
#     'url': 'https://i.scdn.co/image/6ca7a7068aa8fb30d07faf356307e8a399c1d986',
#     'width': 200},
#    {'height': 51,
#     'url': 'https://i.scdn.co/image/60cc3e832a9e27acb8903638e566b6fe98802bac',
#     'width': 64}],
#   'name': '+44',
#   'popularity': 53,
#   'type': 'artist',
#   'uri': 'spotify:artist:7gkRNHOOt7QfhhXf0rEnmj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0qT79UgT5tY4yudH9VfsdT'},
#   'followers': {'href': None, 'total': 3504774},
#   'genres': ['canadian pop punk', 'canadian punk', 'punk'],
#   'href': 'https://api.spotify.com/v1/artists/0qT79UgT5tY4yudH9VfsdT',
#   'id': '0qT79UgT5tY4yudH9VfsdT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba79683a6e828e1a86341414c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a79683a6e828e1a86341414c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a79683a6e828e1a86341414c',
#     'width': 160}],
#   'name': 'Sum 41',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:0qT79UgT5tY4yudH9VfsdT'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DK7FqcaL3ks9TfFn9y1sD'},
#   'followers': {'href': None, 'total': 385444},
#   'genres': ['pop punk', 'punk', 'skate punk'],
#   'href': 'https://api.spotify.com/v1/artists/0DK7FqcaL3ks9TfFn9y1sD',
#   'id': '0DK7FqcaL3ks9TfFn9y1sD',
#   'images': [{'height': 1000,
#     'url': 'https://i.scdn.co/image/420feb7fab6622848736cff1aa11739eae13849f',
#     'width': 1000},
#    {'height': 640,
#     'url': 'https://i.scdn.co/image/677591bff2b6391532f1e14bbeb32f043be3f307',
#     'width': 640},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/85d1309dd1ab243f07ba898583d00be0409f394d',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/b1d98d120878dae011615b826fbd848370f57c97',
#     'width': 64}],
#   'name': 'Box Car Racer',
#   'popularity': 52,
#   'type': 'artist',
#   'uri': 'spotify:artist:0DK7FqcaL3ks9TfFn9y1sD'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5aYyPjAsLj7UzANzdupwnS'},
#   'followers': {'href': None, 'total': 2371471},
#   'genres': ['alternative metal', 'pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/5aYyPjAsLj7UzANzdupwnS',
#   'id': '5aYyPjAsLj7UzANzdupwnS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb42c5b40a82c6349adc1449a2',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517442c5b40a82c6349adc1449a2',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17842c5b40a82c6349adc1449a2',
#     'width': 160}],
#   'name': 'Good Charlotte',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:5aYyPjAsLj7UzANzdupwnS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#   'followers': {'href': None, 'total': 1038555},
#   'genres': ['comic', 'pop punk', 'pop rock', 'texas pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#   'id': '5ND0mGcL9SKSjWIjPd0xIb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb431720ffc823f2babce011f9',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174431720ffc823f2babce011f9',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178431720ffc823f2babce011f9',
#     'width': 160}],
#   'name': 'Bowling For Soup',
#   'popularity': 63,
#   'type': 'artist',
#   'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3zxKH0qp3nBCuPZCZT5Vaf'},
#   'followers': {'href': None, 'total': 1384423},
#   'genres': ['bow pop', 'pop punk', 'socal pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/3zxKH0qp3nBCuPZCZT5Vaf',
#   'id': '3zxKH0qp3nBCuPZCZT5Vaf',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb952381a70ceeda02554ad545',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174952381a70ceeda02554ad545',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178952381a70ceeda02554ad545',
#     'width': 160}],
#   'name': 'Yellowcard',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:3zxKH0qp3nBCuPZCZT5Vaf'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p4FqHnazRucYQHyDCdBrJ'},
#   'followers': {'href': None, 'total': 3355793},
#   'genres': ['canadian pop punk',
#    'canadian punk',
#    'canadian rock',
#    'pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/2p4FqHnazRucYQHyDCdBrJ',
#   'id': '2p4FqHnazRucYQHyDCdBrJ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb14be52ba7ed12e0177ebe08b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517414be52ba7ed12e0177ebe08b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17814be52ba7ed12e0177ebe08b',
#     'width': 160}],
#   'name': 'Simple Plan',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:2p4FqHnazRucYQHyDCdBrJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#   'followers': {'href': None, 'total': 1391153},
#   'genres': ['alternative rock',
#    'emo',
#    'modern power pop',
#    'modern rock',
#    'neo mellow',
#    'pop punk',
#    'pop rock',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#   'id': '3Ayl7mCk0nScecqOzvNp6s',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb0dc33cfd207772f8e2f6b46f',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051740dc33cfd207772f8e2f6b46f',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1780dc33cfd207772f8e2f6b46f',
#     'width': 160}],
#   'name': 'Jimmy Eat World',
#   'popularity': 69,
#   'type': 'artist',
#   'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vAaWhdBR38Q02ohXqaNHT'},
#   'followers': {'href': None, 'total': 2463888},
#   'genres': ['modern rock', 'neo mellow', 'pop punk', 'pop rock'],
#   'href': 'https://api.spotify.com/v1/artists/3vAaWhdBR38Q02ohXqaNHT',
#   'id': '3vAaWhdBR38Q02ohXqaNHT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb57332e3fc2b97bb33577e65',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b57332e3fc2b97bb33577e65',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b57332e3fc2b97bb33577e65',
#     'width': 160}],
#   'name': 'The All-American Rejects',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:3vAaWhdBR38Q02ohXqaNHT'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6SiyKSeJo6gcsS2NvuAbsl'},
#   'followers': {'href': None, 'total': 314935},
#   'genres': ['funk metal', 'pop punk', 'punk', 'rap rock', 'skate punk'],
#   'href': 'https://api.spotify.com/v1/artists/6SiyKSeJo6gcsS2NvuAbsl',
#   'id': '6SiyKSeJo6gcsS2NvuAbsl',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb05fe18f0e91beba7775bbc77',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517405fe18f0e91beba7775bbc77',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17805fe18f0e91beba7775bbc77',
#     'width': 160}],
#   'name': 'zebrahead',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:6SiyKSeJo6gcsS2NvuAbsl'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ghjRm4M2vChDfTUycx0Ce'},
#   'followers': {'href': None, 'total': 772271},
#   'genres': ['easycore', 'emo', 'pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/4ghjRm4M2vChDfTUycx0Ce',
#   'id': '4ghjRm4M2vChDfTUycx0Ce',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb83d2bd8df5ef51c19c48addb',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517483d2bd8df5ef51c19c48addb',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17883d2bd8df5ef51c19c48addb',
#     'width': 160}],
#   'name': 'New Found Glory',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:4ghjRm4M2vChDfTUycx0Ce'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/04RtvnUz0XrUbUZzOA8ZoW'},
#   'followers': {'href': None, 'total': 261508},
#   'genres': ['emo', 'neon pop punk', 'pop punk', 'punk'],
#   'href': 'https://api.spotify.com/v1/artists/04RtvnUz0XrUbUZzOA8ZoW',
#   'id': '04RtvnUz0XrUbUZzOA8ZoW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb86bc3dbfacb4a34317d47cd8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517486bc3dbfacb4a34317d47cd8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17886bc3dbfacb4a34317d47cd8',
#     'width': 160}],
#   'name': 'Sugarcult',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:04RtvnUz0XrUbUZzOA8ZoW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cSpfa4Un4NCOzeOKgGtG9'},
#   'followers': {'href': None, 'total': 229555},
#   'genres': ['christian punk', 'pop punk', 'punk', 'skate punk'],
#   'href': 'https://api.spotify.com/v1/artists/1cSpfa4Un4NCOzeOKgGtG9',
#   'id': '1cSpfa4Un4NCOzeOKgGtG9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd27e7ccd2621732d0acdd01a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d27e7ccd2621732d0acdd01a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d27e7ccd2621732d0acdd01a',
#     'width': 160}],
#   'name': 'MxPx',
#   'popularity': 50,
#   'type': 'artist',
#   'uri': 'spotify:artist:1cSpfa4Un4NCOzeOKgGtG9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sVQKNtdP2NylxMgbNOJMM'},
#   'followers': {'href': None, 'total': 397351},
#   'genres': ['pop punk',
#    'punk',
#    'ska',
#    'ska punk',
#    'skate punk',
#    'socal pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/7sVQKNtdP2NylxMgbNOJMM',
#   'id': '7sVQKNtdP2NylxMgbNOJMM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6e3eb65eeedfd376e6082a4d',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746e3eb65eeedfd376e6082a4d',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786e3eb65eeedfd376e6082a4d',
#     'width': 160}],
#   'name': 'Goldfinger',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:7sVQKNtdP2NylxMgbNOJMM'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#   'followers': {'href': None, 'total': 13868669},
#   'genres': ['permanent wave', 'punk'],
#   'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#   'id': '7oPftvlwr6VrsViSDV7fJY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb047eac333eff0be4abe32cbf',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174047eac333eff0be4abe32cbf',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178047eac333eff0be4abe32cbf',
#     'width': 160}],
#   'name': 'Green Day',
#   'popularity': 81,
#   'type': 'artist',
#   'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/19I4tYiChJoxEO5EuviXpz'},
#   'followers': {'href': None, 'total': 834622},
#   'genres': ['alternative metal', 'pop punk', 'punk', 'screamo', 'skate punk'],
#   'href': 'https://api.spotify.com/v1/artists/19I4tYiChJoxEO5EuviXpz',
#   'id': '19I4tYiChJoxEO5EuviXpz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebbdecf4762da0117e96e03fb8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174bdecf4762da0117e96e03fb8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178bdecf4762da0117e96e03fb8',
#     'width': 160}],
#   'name': 'AFI',
#   'popularity': 64,
#   'type': 'artist',
#   'uri': 'spotify:artist:19I4tYiChJoxEO5EuviXpz'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6meTcQ79DrfkIuSLPZkpBg'},
#   'followers': {'href': None, 'total': 413398},
#   'genres': ['alternative emo', 'anthem emo', 'emo', 'pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/6meTcQ79DrfkIuSLPZkpBg',
#   'id': '6meTcQ79DrfkIuSLPZkpBg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebf8cc5cd3fbc2f2da9b72ecb5',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174f8cc5cd3fbc2f2da9b72ecb5',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178f8cc5cd3fbc2f2da9b72ecb5',
#     'width': 160}],
#   'name': 'The Story So Far',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:6meTcQ79DrfkIuSLPZkpBg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#   'followers': {'href': None, 'total': 4940604},
#   'genres': ['alternative metal',
#    'permanent wave',
#    'punk',
#    'rock',
#    'skate punk',
#    'socal pop punk'],
#   'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#   'id': '5LfGQac0EIXyAN8aUwmNAQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd7c5bbf32459922a72ec0d31',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d7c5bbf32459922a72ec0d31',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d7c5bbf32459922a72ec0d31',
#     'width': 160}],
#   'name': 'The Offspring',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0qqxspZOkbN00bu6DaRIrn'},
#   'followers': {'href': None, 'total': 233205},
#   'genres': ['alternative emo',
#    'anthem emo',
#    'easycore',
#    'emo',
#    'neon pop punk',
#    'new england emo',
#    'pop punk',
#    'screamo',
#    'worcester ma indie'],
#   'href': 'https://api.spotify.com/v1/artists/0qqxspZOkbN00bu6DaRIrn',
#   'id': '0qqxspZOkbN00bu6DaRIrn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebff59f88ad0ad213be1565d8f',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ff59f88ad0ad213be1565d8f',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ff59f88ad0ad213be1565d8f',
#     'width': 160}],
#   'name': 'Four Year Strong',
#   'popularity': 52,
#   'type': 'artist',
#   'uri': 'spotify:artist:0qqxspZOkbN00bu6DaRIrn'}]

# %%
artists_related['artists'][1]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gkRNHOOt7QfhhXf0rEnmj'},
#  'followers': {'href': None, 'total': 406254},
#  'genres': ['pop punk', 'punk', 'skate punk'],
#  'href': 'https://api.spotify.com/v1/artists/7gkRNHOOt7QfhhXf0rEnmj',
#  'id': '7gkRNHOOt7QfhhXf0rEnmj',
#  'images': [{'height': 714,
#    'url': 'https://i.scdn.co/image/2ffba921f9db6d1bf44ae63b8a956e3a11fea234',
#    'width': 900},
#   {'height': 508,
#    'url': 'https://i.scdn.co/image/40baeadac6642e10437833f0ba1006eda0d22786',
#    'width': 640},
#   {'height': 159,
#    'url': 'https://i.scdn.co/image/6ca7a7068aa8fb30d07faf356307e8a399c1d986',
#    'width': 200},
#   {'height': 51,
#    'url': 'https://i.scdn.co/image/60cc3e832a9e27acb8903638e566b6fe98802bac',
#    'width': 64}],
#  'name': '+44',
#  'popularity': 53,
#  'type': 'artist',
#  'uri': 'spotify:artist:7gkRNHOOt7QfhhXf0rEnmj'}

# %%
artists_related['artists'][0]['id']
# Out:
# '7xklw3WodFZiNNmQt3DIgp'

# %%
pd.DataFrame(artists_related['artists'])
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/7...
# 1   {'spotify': 'https://open.spotify.com/artist/7...
# 2   {'spotify': 'https://open.spotify.com/artist/0...
# 3   {'spotify': 'https://open.spotify.com/artist/0...
# 4   {'spotify': 'https://open.spotify.com/artist/5...
# 5   {'spotify': 'https://open.spotify.com/artist/5...
# 6   {'spotify': 'https://open.spotify.com/artist/3...
# 7   {'spotify': 'https://open.spotify.com/artist/2...
# 8   {'spotify': 'https://open.spotify.com/artist/3...
# 9   {'spotify': 'https://open.spotify.com/artist/3...
# 10  {'spotify': 'https://open.spotify.com/artist/6...
# 11  {'spotify': 'https://open.spotify.com/artist/4...
# 12  {'spotify': 'https://open.spotify.com/artist/0...
# 13  {'spotify': 'https://open.spotify.com/artist/1...
# 14  {'spotify': 'https://open.spotify.com/artist/7...
# 15  {'spotify': 'https://open.spotify.com/artist/7...
# 16  {'spotify': 'https://open.spotify.com/artist/1...
# 17  {'spotify': 'https://open.spotify.com/artist/6...
# 18  {'spotify': 'https://open.spotify.com/artist/5...
# 19  {'spotify': 'https://open.spotify.com/artist/0...
#
#                             followers  \
# 0     {'href': None, 'total': 655886}
# 1     {'href': None, 'total': 406254}
# 2    {'href': None, 'total': 3504774}
# 3     {'href': None, 'total': 385444}
# 4    {'href': None, 'total': 2371471}
# 5    {'href': None, 'total': 1038555}
# 6    {'href': None, 'total': 1384423}
# 7    {'href': None, 'total': 3355793}
# 8    {'href': None, 'total': 1391153}
# 9    {'href': None, 'total': 2463888}
# 10    {'href': None, 'total': 314935}
# 11    {'href': None, 'total': 772271}
# 12    {'href': None, 'total': 261508}
# 13    {'href': None, 'total': 229555}
# 14    {'href': None, 'total': 397351}
# 15  {'href': None, 'total': 13868669}
# 16    {'href': None, 'total': 834622}
# 17    {'href': None, 'total': 413398}
# 18   {'href': None, 'total': 4940604}
# 19    {'href': None, 'total': 233205}
#
#                                                genres  \
# 0                          [pop punk, socal pop punk]
# 1                        [pop punk, punk, skate punk]
# 2            [canadian pop punk, canadian punk, punk]
# 3                        [pop punk, punk, skate punk]
# 4                       [alternative metal, pop punk]
# 5         [comic, pop punk, pop rock, texas pop punk]
# 6                 [bow pop, pop punk, socal pop punk]
# 7   [canadian pop punk, canadian punk, canadian ro...
# 8   [alternative rock, emo, modern power pop, mode...
# 9       [modern rock, neo mellow, pop punk, pop rock]
# 10  [funk metal, pop punk, punk, rap rock, skate p...
# 11                          [easycore, emo, pop punk]
# 12               [emo, neon pop punk, pop punk, punk]
# 13       [christian punk, pop punk, punk, skate punk]
# 14  [pop punk, punk, ska, ska punk, skate punk, so...
# 15                             [permanent wave, punk]
# 16  [alternative metal, pop punk, punk, screamo, s...
# 17       [alternative emo, anthem emo, emo, pop punk]
# 18  [alternative metal, permanent wave, punk, rock...
# 19  [alternative emo, anthem emo, easycore, emo, n...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/7xklw3WodFZ...  7xklw3WodFZiNNmQt3DIgp
# 1   https://api.spotify.com/v1/artists/7gkRNHOOt7Q...  7gkRNHOOt7QfhhXf0rEnmj
# 2   https://api.spotify.com/v1/artists/0qT79UgT5tY...  0qT79UgT5tY4yudH9VfsdT
# 3   https://api.spotify.com/v1/artists/0DK7FqcaL3k...  0DK7FqcaL3ks9TfFn9y1sD
# 4   https://api.spotify.com/v1/artists/5aYyPjAsLj7...  5aYyPjAsLj7UzANzdupwnS
# 5   https://api.spotify.com/v1/artists/5ND0mGcL9SK...  5ND0mGcL9SKSjWIjPd0xIb
# 6   https://api.spotify.com/v1/artists/3zxKH0qp3nB...  3zxKH0qp3nBCuPZCZT5Vaf
# 7   https://api.spotify.com/v1/artists/2p4FqHnazRu...  2p4FqHnazRucYQHyDCdBrJ
# 8   https://api.spotify.com/v1/artists/3Ayl7mCk0nS...  3Ayl7mCk0nScecqOzvNp6s
# 9   https://api.spotify.com/v1/artists/3vAaWhdBR38...  3vAaWhdBR38Q02ohXqaNHT
# 10  https://api.spotify.com/v1/artists/6SiyKSeJo6g...  6SiyKSeJo6gcsS2NvuAbsl
# 11  https://api.spotify.com/v1/artists/4ghjRm4M2vC...  4ghjRm4M2vChDfTUycx0Ce
# 12  https://api.spotify.com/v1/artists/04RtvnUz0Xr...  04RtvnUz0XrUbUZzOA8ZoW
# 13  https://api.spotify.com/v1/artists/1cSpfa4Un4N...  1cSpfa4Un4NCOzeOKgGtG9
# 14  https://api.spotify.com/v1/artists/7sVQKNtdP2N...  7sVQKNtdP2NylxMgbNOJMM
# 15  https://api.spotify.com/v1/artists/7oPftvlwr6V...  7oPftvlwr6VrsViSDV7fJY
# 16  https://api.spotify.com/v1/artists/19I4tYiChJo...  19I4tYiChJoxEO5EuviXpz
# 17  https://api.spotify.com/v1/artists/6meTcQ79Drf...  6meTcQ79DrfkIuSLPZkpBg
# 18  https://api.spotify.com/v1/artists/5LfGQac0EIX...  5LfGQac0EIXyAN8aUwmNAQ
# 19  https://api.spotify.com/v1/artists/0qqxspZOkbN...  0qqxspZOkbN00bu6DaRIrn
#
#                                                images  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   [{'height': 714, 'url': 'https://i.scdn.co/ima...
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   [{'height': 1000, 'url': 'https://i.scdn.co/im...
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                         name  popularity    type  \
# 0          Angels & Airwaves          59  artist
# 1                        +44          53  artist
# 2                     Sum 41          73  artist
# 3              Box Car Racer          52  artist
# 4             Good Charlotte          68  artist
# 5           Bowling For Soup          63  artist
# 6                 Yellowcard          65  artist
# 7                Simple Plan          71  artist
# 8            Jimmy Eat World          69  artist
# 9   The All-American Rejects          68  artist
# 10                 zebrahead          57  artist
# 11           New Found Glory          61  artist
# 12                 Sugarcult          54  artist
# 13                      MxPx          50  artist
# 14                Goldfinger          58  artist
# 15                 Green Day          81  artist
# 16                       AFI          64  artist
# 17          The Story So Far          61  artist
# 18             The Offspring          78  artist
# 19          Four Year Strong          52  artist
#
#                                       uri
# 0   spotify:artist:7xklw3WodFZiNNmQt3DIgp
# 1   spotify:artist:7gkRNHOOt7QfhhXf0rEnmj
# 2   spotify:artist:0qT79UgT5tY4yudH9VfsdT
# 3   spotify:artist:0DK7FqcaL3ks9TfFn9y1sD
# 4   spotify:artist:5aYyPjAsLj7UzANzdupwnS
# 5   spotify:artist:5ND0mGcL9SKSjWIjPd0xIb
# 6   spotify:artist:3zxKH0qp3nBCuPZCZT5Vaf
# 7   spotify:artist:2p4FqHnazRucYQHyDCdBrJ
# 8   spotify:artist:3Ayl7mCk0nScecqOzvNp6s
# 9   spotify:artist:3vAaWhdBR38Q02ohXqaNHT
# 10  spotify:artist:6SiyKSeJo6gcsS2NvuAbsl
# 11  spotify:artist:4ghjRm4M2vChDfTUycx0Ce
# 12  spotify:artist:04RtvnUz0XrUbUZzOA8ZoW
# 13  spotify:artist:1cSpfa4Un4NCOzeOKgGtG9
# 14  spotify:artist:7sVQKNtdP2NylxMgbNOJMM
# 15  spotify:artist:7oPftvlwr6VrsViSDV7fJY
# 16  spotify:artist:19I4tYiChJoxEO5EuviXpz
# 17  spotify:artist:6meTcQ79DrfkIuSLPZkpBg
# 18  spotify:artist:5LfGQac0EIXyAN8aUwmNAQ
# 19  spotify:artist:0qqxspZOkbN00bu6DaRIrn

# %%
pd.DataFrame(artists_related['artists'], columns=['id'])
# Out:
#                         id
# 0   7xklw3WodFZiNNmQt3DIgp
# 1   7gkRNHOOt7QfhhXf0rEnmj
# 2   0qT79UgT5tY4yudH9VfsdT
# 3   0DK7FqcaL3ks9TfFn9y1sD
# 4   5aYyPjAsLj7UzANzdupwnS
# 5   5ND0mGcL9SKSjWIjPd0xIb
# 6   3zxKH0qp3nBCuPZCZT5Vaf
# 7   2p4FqHnazRucYQHyDCdBrJ
# 8   3Ayl7mCk0nScecqOzvNp6s
# 9   3vAaWhdBR38Q02ohXqaNHT
# 10  6SiyKSeJo6gcsS2NvuAbsl
# 11  4ghjRm4M2vChDfTUycx0Ce
# 12  04RtvnUz0XrUbUZzOA8ZoW
# 13  1cSpfa4Un4NCOzeOKgGtG9
# 14  7sVQKNtdP2NylxMgbNOJMM
# 15  7oPftvlwr6VrsViSDV7fJY
# 16  19I4tYiChJoxEO5EuviXpz
# 17  6meTcQ79DrfkIuSLPZkpBg
# 18  5LfGQac0EIXyAN8aUwmNAQ
# 19  0qqxspZOkbN00bu6DaRIrn

# %%
# top tracks of related artists

# %%
artists_list = [artists_related['artists'][artista]['id'] for artista in range(len(artists_related['artists']))]
artists_list
# Out:
# ['7xklw3WodFZiNNmQt3DIgp',
#  '7gkRNHOOt7QfhhXf0rEnmj',
#  '0qT79UgT5tY4yudH9VfsdT',
#  '0DK7FqcaL3ks9TfFn9y1sD',
#  '5aYyPjAsLj7UzANzdupwnS',
#  '5ND0mGcL9SKSjWIjPd0xIb',
#  '3zxKH0qp3nBCuPZCZT5Vaf',
#  '2p4FqHnazRucYQHyDCdBrJ',
#  '3Ayl7mCk0nScecqOzvNp6s',
#  '3vAaWhdBR38Q02ohXqaNHT',
#  '6SiyKSeJo6gcsS2NvuAbsl',
#  '4ghjRm4M2vChDfTUycx0Ce',
#  '04RtvnUz0XrUbUZzOA8ZoW',
#  '1cSpfa4Un4NCOzeOKgGtG9',
#  '7sVQKNtdP2NylxMgbNOJMM',
#  '7oPftvlwr6VrsViSDV7fJY',
#  '19I4tYiChJoxEO5EuviXpz',
#  '6meTcQ79DrfkIuSLPZkpBg',
#  '5LfGQac0EIXyAN8aUwmNAQ',
#  '0qqxspZOkbN00bu6DaRIrn']

# %%
full_endpoint_02 = full_endpoint1 + method_02 + country
print(full_endpoint_02)

res_02 = requests.get(full_endpoint_02, headers=header_info)
res_02
# Out:
# https://api.spotify.com/v1/artists/6FBDaR13swtiWwGhX1WQsP/top-tracks?country=ES
# <Response [200]>

# %%
artists_related
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xklw3WodFZiNNmQt3DIgp'},
#    'followers': {'href': None, 'total': 655886},
#    'genres': ['pop punk', 'socal pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/7xklw3WodFZiNNmQt3DIgp',
#    'id': '7xklw3WodFZiNNmQt3DIgp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9bf03fdd68eecd329f9fde6e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749bf03fdd68eecd329f9fde6e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789bf03fdd68eecd329f9fde6e',
#      'width': 160}],
#    'name': 'Angels & Airwaves',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:7xklw3WodFZiNNmQt3DIgp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gkRNHOOt7QfhhXf0rEnmj'},
#    'followers': {'href': None, 'total': 406254},
#    'genres': ['pop punk', 'punk', 'skate punk'],
#    'href': 'https://api.spotify.com/v1/artists/7gkRNHOOt7QfhhXf0rEnmj',
#    'id': '7gkRNHOOt7QfhhXf0rEnmj',
#    'images': [{'height': 714,
#      'url': 'https://i.scdn.co/image/2ffba921f9db6d1bf44ae63b8a956e3a11fea234',
#      'width': 900},
#     {'height': 508,
#      'url': 'https://i.scdn.co/image/40baeadac6642e10437833f0ba1006eda0d22786',
#      'width': 640},
#     {'height': 159,
#      'url': 'https://i.scdn.co/image/6ca7a7068aa8fb30d07faf356307e8a399c1d986',
#      'width': 200},
#     {'height': 51,
#      'url': 'https://i.scdn.co/image/60cc3e832a9e27acb8903638e566b6fe98802bac',
#      'width': 64}],
#    'name': '+44',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:7gkRNHOOt7QfhhXf0rEnmj'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0qT79UgT5tY4yudH9VfsdT'},
#    'followers': {'href': None, 'total': 3504774},
#    'genres': ['canadian pop punk', 'canadian punk', 'punk'],
#    'href': 'https://api.spotify.com/v1/artists/0qT79UgT5tY4yudH9VfsdT',
#    'id': '0qT79UgT5tY4yudH9VfsdT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba79683a6e828e1a86341414c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a79683a6e828e1a86341414c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a79683a6e828e1a86341414c',
#      'width': 160}],
#    'name': 'Sum 41',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:0qT79UgT5tY4yudH9VfsdT'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DK7FqcaL3ks9TfFn9y1sD'},
#    'followers': {'href': None, 'total': 385444},
#    'genres': ['pop punk', 'punk', 'skate punk'],
#    'href': 'https://api.spotify.com/v1/artists/0DK7FqcaL3ks9TfFn9y1sD',
#    'id': '0DK7FqcaL3ks9TfFn9y1sD',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/420feb7fab6622848736cff1aa11739eae13849f',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/677591bff2b6391532f1e14bbeb32f043be3f307',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/85d1309dd1ab243f07ba898583d00be0409f394d',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/b1d98d120878dae011615b826fbd848370f57c97',
#      'width': 64}],
#    'name': 'Box Car Racer',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:0DK7FqcaL3ks9TfFn9y1sD'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5aYyPjAsLj7UzANzdupwnS'},
#    'followers': {'href': None, 'total': 2371471},
#    'genres': ['alternative metal', 'pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/5aYyPjAsLj7UzANzdupwnS',
#    'id': '5aYyPjAsLj7UzANzdupwnS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb42c5b40a82c6349adc1449a2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517442c5b40a82c6349adc1449a2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17842c5b40a82c6349adc1449a2',
#      'width': 160}],
#    'name': 'Good Charlotte',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:5aYyPjAsLj7UzANzdupwnS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#    'followers': {'href': None, 'total': 1038555},
#    'genres': ['comic', 'pop punk', 'pop rock', 'texas pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#    'id': '5ND0mGcL9SKSjWIjPd0xIb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb431720ffc823f2babce011f9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174431720ffc823f2babce011f9',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178431720ffc823f2babce011f9',
#      'width': 160}],
#    'name': 'Bowling For Soup',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3zxKH0qp3nBCuPZCZT5Vaf'},
#    'followers': {'href': None, 'total': 1384423},
#    'genres': ['bow pop', 'pop punk', 'socal pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/3zxKH0qp3nBCuPZCZT5Vaf',
#    'id': '3zxKH0qp3nBCuPZCZT5Vaf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb952381a70ceeda02554ad545',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174952381a70ceeda02554ad545',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178952381a70ceeda02554ad545',
#      'width': 160}],
#    'name': 'Yellowcard',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:3zxKH0qp3nBCuPZCZT5Vaf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p4FqHnazRucYQHyDCdBrJ'},
#    'followers': {'href': None, 'total': 3355793},
#    'genres': ['canadian pop punk',
#     'canadian punk',
#     'canadian rock',
#     'pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/2p4FqHnazRucYQHyDCdBrJ',
#    'id': '2p4FqHnazRucYQHyDCdBrJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb14be52ba7ed12e0177ebe08b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517414be52ba7ed12e0177ebe08b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17814be52ba7ed12e0177ebe08b',
#      'width': 160}],
#    'name': 'Simple Plan',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:2p4FqHnazRucYQHyDCdBrJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#    'followers': {'href': None, 'total': 1391153},
#    'genres': ['alternative rock',
#     'emo',
#     'modern power pop',
#     'modern rock',
#     'neo mellow',
#     'pop punk',
#     'pop rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#    'id': '3Ayl7mCk0nScecqOzvNp6s',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb0dc33cfd207772f8e2f6b46f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051740dc33cfd207772f8e2f6b46f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1780dc33cfd207772f8e2f6b46f',
#      'width': 160}],
#    'name': 'Jimmy Eat World',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vAaWhdBR38Q02ohXqaNHT'},
#    'followers': {'href': None, 'total': 2463888},
#    'genres': ['modern rock', 'neo mellow', 'pop punk', 'pop rock'],
#    'href': 'https://api.spotify.com/v1/artists/3vAaWhdBR38Q02ohXqaNHT',
#    'id': '3vAaWhdBR38Q02ohXqaNHT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebb57332e3fc2b97bb33577e65',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174b57332e3fc2b97bb33577e65',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178b57332e3fc2b97bb33577e65',
#      'width': 160}],
#    'name': 'The All-American Rejects',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:3vAaWhdBR38Q02ohXqaNHT'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6SiyKSeJo6gcsS2NvuAbsl'},
#    'followers': {'href': None, 'total': 314935},
#    'genres': ['funk metal', 'pop punk', 'punk', 'rap rock', 'skate punk'],
#    'href': 'https://api.spotify.com/v1/artists/6SiyKSeJo6gcsS2NvuAbsl',
#    'id': '6SiyKSeJo6gcsS2NvuAbsl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb05fe18f0e91beba7775bbc77',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517405fe18f0e91beba7775bbc77',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17805fe18f0e91beba7775bbc77',
#      'width': 160}],
#    'name': 'zebrahead',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:6SiyKSeJo6gcsS2NvuAbsl'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ghjRm4M2vChDfTUycx0Ce'},
#    'followers': {'href': None, 'total': 772271},
#    'genres': ['easycore', 'emo', 'pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/4ghjRm4M2vChDfTUycx0Ce',
#    'id': '4ghjRm4M2vChDfTUycx0Ce',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb83d2bd8df5ef51c19c48addb',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517483d2bd8df5ef51c19c48addb',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17883d2bd8df5ef51c19c48addb',
#      'width': 160}],
#    'name': 'New Found Glory',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:4ghjRm4M2vChDfTUycx0Ce'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/04RtvnUz0XrUbUZzOA8ZoW'},
#    'followers': {'href': None, 'total': 261508},
#    'genres': ['emo', 'neon pop punk', 'pop punk', 'punk'],
#    'href': 'https://api.spotify.com/v1/artists/04RtvnUz0XrUbUZzOA8ZoW',
#    'id': '04RtvnUz0XrUbUZzOA8ZoW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb86bc3dbfacb4a34317d47cd8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517486bc3dbfacb4a34317d47cd8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17886bc3dbfacb4a34317d47cd8',
#      'width': 160}],
#    'name': 'Sugarcult',
#    'popularity': 54,
#    'type': 'artist',
#    'uri': 'spotify:artist:04RtvnUz0XrUbUZzOA8ZoW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cSpfa4Un4NCOzeOKgGtG9'},
#    'followers': {'href': None, 'total': 229555},
#    'genres': ['christian punk', 'pop punk', 'punk', 'skate punk'],
#    'href': 'https://api.spotify.com/v1/artists/1cSpfa4Un4NCOzeOKgGtG9',
#    'id': '1cSpfa4Un4NCOzeOKgGtG9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebd27e7ccd2621732d0acdd01a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174d27e7ccd2621732d0acdd01a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178d27e7ccd2621732d0acdd01a',
#      'width': 160}],
#    'name': 'MxPx',
#    'popularity': 50,
#    'type': 'artist',
#    'uri': 'spotify:artist:1cSpfa4Un4NCOzeOKgGtG9'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sVQKNtdP2NylxMgbNOJMM'},
#    'followers': {'href': None, 'total': 397351},
#    'genres': ['pop punk',
#     'punk',
#     'ska',
#     'ska punk',
#     'skate punk',
#     'socal pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/7sVQKNtdP2NylxMgbNOJMM',
#    'id': '7sVQKNtdP2NylxMgbNOJMM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6e3eb65eeedfd376e6082a4d',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746e3eb65eeedfd376e6082a4d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786e3eb65eeedfd376e6082a4d',
#      'width': 160}],
#    'name': 'Goldfinger',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:7sVQKNtdP2NylxMgbNOJMM'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#    'followers': {'href': None, 'total': 13868669},
#    'genres': ['permanent wave', 'punk'],
#    'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#    'id': '7oPftvlwr6VrsViSDV7fJY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb047eac333eff0be4abe32cbf',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174047eac333eff0be4abe32cbf',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178047eac333eff0be4abe32cbf',
#      'width': 160}],
#    'name': 'Green Day',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/19I4tYiChJoxEO5EuviXpz'},
#    'followers': {'href': None, 'total': 834622},
#    'genres': ['alternative metal',
#     'pop punk',
#     'punk',
#     'screamo',
#     'skate punk'],
#    'href': 'https://api.spotify.com/v1/artists/19I4tYiChJoxEO5EuviXpz',
#    'id': '19I4tYiChJoxEO5EuviXpz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebbdecf4762da0117e96e03fb8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174bdecf4762da0117e96e03fb8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178bdecf4762da0117e96e03fb8',
#      'width': 160}],
#    'name': 'AFI',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:19I4tYiChJoxEO5EuviXpz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6meTcQ79DrfkIuSLPZkpBg'},
#    'followers': {'href': None, 'total': 413398},
#    'genres': ['alternative emo', 'anthem emo', 'emo', 'pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/6meTcQ79DrfkIuSLPZkpBg',
#    'id': '6meTcQ79DrfkIuSLPZkpBg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebf8cc5cd3fbc2f2da9b72ecb5',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174f8cc5cd3fbc2f2da9b72ecb5',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178f8cc5cd3fbc2f2da9b72ecb5',
#      'width': 160}],
#    'name': 'The Story So Far',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:6meTcQ79DrfkIuSLPZkpBg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#    'followers': {'href': None, 'total': 4940604},
#    'genres': ['alternative metal',
#     'permanent wave',
#     'punk',
#     'rock',
#     'skate punk',
#     'socal pop punk'],
#    'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#    'id': '5LfGQac0EIXyAN8aUwmNAQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebd7c5bbf32459922a72ec0d31',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174d7c5bbf32459922a72ec0d31',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178d7c5bbf32459922a72ec0d31',
#      'width': 160}],
#    'name': 'The Offspring',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0qqxspZOkbN00bu6DaRIrn'},
#    'followers': {'href': None, 'total': 233205},
#    'genres': ['alternative emo',
#     'anthem emo',
#     'easycore',
#     'emo',
#     'neon pop punk',
#     'new england emo',
#     'pop punk',
#     'screamo',
#     'worcester ma indie'],
#    'href': 'https://api.spotify.com/v1/artists/0qqxspZOkbN00bu6DaRIrn',
#    'id': '0qqxspZOkbN00bu6DaRIrn',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebff59f88ad0ad213be1565d8f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174ff59f88ad0ad213be1565d8f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178ff59f88ad0ad213be1565d8f',
#      'width': 160}],
#    'name': 'Four Year Strong',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:0qqxspZOkbN00bu6DaRIrn'}]}

# %%
full_endpoint_03 = base_url + resource + '{}/' + method_02 + country
print(full_endpoint_03)

for artist in artists_list:
    response = requests.get(full_endpoint_03.format(artist), headers=header_info)
    print([response.json()['tracks'][track]['name'] for track in range(len(response.json()['tracks']))])
# Out:
# https://api.spotify.com/v1/artists/{}/top-tracks?country=ES
# ['The Adventure', 'Paper Thin - Headhunterz Remix', "Everything's Magic", 'Paper Thin', 'Sirens', 'Secret Crowds', 'The War', 'Surrender', 'Call To Arms', 'Kiss & Tell']
# ['When Your Heart Stops Beating', "No, It Isn't", 'Baby Come On', '155', 'Lycanthrope', 'Make You Smile', 'Baby Come On - Acoustic Version', 'Cliff Diving', 'Chapter 13/Non-Musical Silence', 'Little Death']
# ['In Too Deep', 'Still Waiting', 'Fat Lip', 'The Hell Song', 'Pieces', 'Over My Head (Better Off Dead)', 'With Me', 'War', 'Underclass Hero', 'No Reason']
# ['There Is', 'I Feel So', 'And I', 'Elevator', 'Letters To God', 'All Systems Go', 'Cat Like Thief', 'Watch The World', 'Tiny Voices', 'Sorrow']
# ['The Anthem', 'Lifestyles of the Rich & Famous', 'The River', "I Don't Wanna Be In Love (Dance Floor Anthem)", 'I Just Wanna Live', 'Girls & Boys', 'Little Things', 'TAKE THIS CROWN (feat. Good Charlotte)', "Like It's Her Birthday", 'SELF-SABOTAGE (feat. Good Charlotte)']
# ['1985', 'Girl All the Bad Guys Want', 'High School Never Ends - Main Version - Explicit', "Stacy's Mom", 'Almost', 'Ohio (Come Back To Texas)', 'I Ran (So Far Away)', 'Today is Gonna be a Great Day', 'Punk Rock 101', 'Flowers']
# ['Ocean Avenue', 'Only One', 'Lights And Sounds', 'Breathing', 'Way Away', 'For You, And Your Denial', 'Fighting', 'Light Up The Sky', 'Everywhere', 'Empty Apartment']
# ["I'm Just a Kid", 'Welcome to My Life', 'Perfect', 'Summer Paradise (feat. Sean Paul) - Single Version', 'Jet Lag (feat. Natasha Bedingfield)', "I'd Do Anything", "What's New Scooby-Doo?", 'Addicted', 'Shut Up!', 'Untitled (How Could This Happen to Me?)']
# ['The Middle', 'Sweetness', 'Bleed American', 'Pain', 'Hear You Me', 'The Middle - Acoustic Version', 'A Praise Chorus', 'Work', 'Just Tonight', 'Big Casino']
# ['Gives You Hell', 'Dirty Little Secret', 'Move Along', 'Swing, Swing', 'It Ends Tonight', 'I Wanna', 'My Paper Heart', 'Top Of The World', 'The Last Song', 'Sweat']
# ['All My Friends Are Nobodies', 'Falling Apart', 'Anthem', 'The Perfect Crime', 'We’re Not Alright', 'Out of Control', 'Hell Yeah!', 'When Both Sides Suck, We’re All Winners', 'Middle Seat Blues', 'Hello Tomorrow']
# ['My Friends Over You', 'All Downhill From Here', 'Kiss Me', 'Hit Or Miss', 'Vicious Love (feat. Hayley Williams)', 'Hold My Hand', 'King Of Wishful Thinking', 'Iris', 'This Is Me', 'Understatement']
# ['Memory', 'Bouncing Off The Walls', 'Los Angeles', 'Stuck In America', 'Pretty Girl (The Way)', 'Do It Alone', 'Memory - Acoustic Version', "She's the Blade", 'Dead Living', 'Hate Every Beautiful Day']
# ["Let's Ride", 'Kids In America', 'Secret Weapon', 'Worries', 'Responsibility', 'Wrecking Hotel Rooms', 'Chick Magnet', 'Heard That Sound', 'Punk Rawk Show', "(I'm Gonna Be) 500 Miles"]
# ['Superman', '99 Red Balloons', 'Here In Your Bedroom', 'Spokesman', 'Tijuana Sunrise', 'Wallflower', 'Get Up', 'Infinite', 'My Everything', 'Put The Knife Away']
# ['Basket Case', 'Boulevard of Broken Dreams', 'American Idiot', 'Good Riddance (Time of Your Life)', 'Wake Me up When September Ends', 'When I Come Around', 'Holiday', '21 Guns', 'Holiday / Boulevard of Broken Dreams', 'Brain Stew']
# ['Miss Murder', "Girl's Not Grey", 'Prelude 12/21', 'The Leaving Song Pt. II', 'Silver And Cold', 'The Boy Who Destroyed The World', 'Dancing Through Sunday', 'The Days Of The Phoenix', 'Love Like Winter', 'Totalimmortal']
# ['Clairvoyant', 'Empty Space', 'Nerve', "Things I Can't Change", 'Keep This Up', 'Heavy Gloom', 'Proper Dose', 'Out of It', 'All Wrong', 'Quicksand']
# ["The Kids Aren't Alright", "You're Gonna Go Far, Kid", 'Self Esteem', 'Pretty Fly (For A White Guy)', "Why Don't You Get A Job", 'Come Out and Play', 'Want You Bad', 'All I Want', 'Gone Away - 1997', "(Can't Get My) Head Around You"]
# ['We All Float Down Here', 'Wasting Time (Eternal Summer)', 'Go Down in History', 'It Must Really Suck To Be Four Year Strong Right Now', 'Heroes Get Remembered, Legends Never Die', "She's So High", 'Talking Myself in Circles', 'Love Song', 'Get out of My Head', 'Learn to Love the Lie']

# %%
#artists_related = pd.DataFrame(artists_related)
#artists_related['artists'] = artists_related['artists'].str.extract(r'(artist/d+)', expand=False)
#artists_related
#artists_related['artists'].map(lambda x: x.lstrip('/').rstrip('+++'))

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
